# %%
import nbformat

# Load the two notebooks
with open("Combined-9.ipynb", "r") as f1, open("Part-10-MediumDataset.ipynb", "r") as f2:
    nb1 = nbformat.read(f1, as_version=4)
    nb2 = nbformat.read(f2, as_version=4)

# Combine the cells
nb1.cells.extend(nb2.cells)

# Save the merged notebook
with open("Combined-10.ipynb", "w") as f_out:
    nbformat.write(nb1, f_out)

print("Notebooks merged successfully into 'combined_notebook.ipynb'")
# Out:
# Notebooks merged successfully into 'combined_notebook.ipynb'
