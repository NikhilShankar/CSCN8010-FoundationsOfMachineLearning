# %% [markdown]
# # **CSCN8010 - Section2**
# ### Practical Lab 3
# #### Vanilla CNN and Fine-Tune VGG16 - for Dogs and Cats Classification
# Prepared by : Nikhil Shankar Chirakkal Sivasankaran (9026254)

# %% [markdown]
# #### **Data Downloading**
#
# - We are downloading the cats vs dogs dataset from kaggle.
# - https://www.kaggle.com/datasets/shaunthesheep/microsoft-catsvsdogs-dataset

# %% [markdown]
# #### **Exploratory Data Analysis**

# %%
from EDAImage import EDAImage
import pandas as pd

class_map = {
    "cat": "data/RawDataset/cat",
    "dog": "data/RawDataset/dog"
}
imageEda = EDAImage(class_map)
image_count = imageEda.get_image_counts()
metadata = imageEda.get_image_metadata()

display(image_count)
display(metadata.head(2))
# Out:
# c:\Users\DELL\Desktop\Conestoga\AIML\FoundationsMachineLearningFramework\git\CSCN8010\venv\tensorflow_cpu\Lib\site-packages\PIL\TiffImagePlugin.py:935: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
#   Class  ImageCount
# 0   cat       12501
# 1   dog       12501
#   Class  Image  Height  Width
# 0   cat  0.jpg     375    500
# 1   cat  1.jpg     281    300

# %% [markdown]
# - There are equal number of data for both classes.
# - 2 images were not of jpg format.
# - After checking the files these are corrupted files. We can replace these files with another image from internet.

# %%
display(metadata.describe())
# Out:
#              Height         Width
# count  25000.000000  25000.000000
# mean     360.994760    404.445240
# std       96.978553    108.978526
# min       33.000000     42.000000
# 25%      302.000000    323.000000
# 50%      375.000000    448.000000
# 75%      421.000000    500.000000
# max      500.000000    500.000000

# %% [markdown]
# - Maximum size is 500 x 500
# - Most of the images are landscape ( mean is higher for width )
# - Minimum size is 4 x 4 need to figure out images like that which might not be very suitable for image classification.

# %%
metadata['Is_Small'] = (metadata['Height'] < 16) & (metadata['Width'] < 16)
small_images_df = metadata[metadata['Is_Small']]
display(len(small_images_df))
display(small_images_df.describe())
display(small_images_df.head(2))
# Out:
# 0
#        Height  Width
# count     0.0    0.0
# mean      NaN    NaN
# std       NaN    NaN
# min       NaN    NaN
# 25%       NaN    NaN
# 50%       NaN    NaN
# 75%       NaN    NaN
# max       NaN    NaN
# Empty DataFrame
# Columns: [Class, Image, Height, Width, Is_Small]
# Index: []

# %%
metadata['Is_Small'] = (metadata['Height'] < 64) & (metadata['Width'] < 64)
small_images_df = metadata[metadata['Is_Small']]
display(len(small_images_df))
display(small_images_df.describe())
display(small_images_df.head(20))
# Out:
# 19
#           Height      Width
# count  19.000000  19.000000
# mean   47.210526  57.315789
# std     7.878092   5.249896
# min    33.000000  42.000000
# 25%    40.500000  58.000000
# 50%    50.000000  60.000000
# 75%    50.000000  60.000000
# max    63.000000  61.000000
#       Class      Image  Height  Width  Is_Small
# 439     cat  10392.jpg      50     50      True
# 4095    cat   2433.jpg      41     60      True
# 6748    cat   4821.jpg      40     60      True
# 7532    cat   5527.jpg      45     60      True
# 7540    cat   5534.jpg      36     60      True
# 8505    cat   6402.jpg      33     60      True
# 8740    cat   6614.jpg      50     50      True
# 10668   cat    835.jpg      60     60      True
# 13230   dog  10654.jpg      53     60      True
# 13318   dog  10733.jpg      63     42      True
# 13333   dog  10747.jpg      39     50      True
# 14376   dog  11686.jpg      48     60      True
# 15363   dog   1324.jpg      45     60      True
# 16322   dog   2188.jpg      55     60      True
# 16838   dog   2652.jpg      50     61      True
# 17185   dog   2965.jpg      50     58      True
# 22137   dog   7421.jpg      50     58      True
# 23413   dog   8570.jpg      50     60      True
# 24674   dog   9705.jpg      39     60      True

# %%
metadata['Is_Small'] = (metadata['Height'] < 64) & (metadata['Width'] < 64)
small_images_df = metadata[metadata['Is_Small']]
display(len(small_images_df))
display(small_images_df.describe())
display(small_images_df.head(20))
# Out:
# 19
#           Height      Width
# count  19.000000  19.000000
# mean   47.210526  57.315789
# std     7.878092   5.249896
# min    33.000000  42.000000
# 25%    40.500000  58.000000
# 50%    50.000000  60.000000
# 75%    50.000000  60.000000
# max    63.000000  61.000000
#       Class      Image  Height  Width  Is_Small
# 439     cat  10392.jpg      50     50      True
# 4095    cat   2433.jpg      41     60      True
# 6748    cat   4821.jpg      40     60      True
# 7532    cat   5527.jpg      45     60      True
# 7540    cat   5534.jpg      36     60      True
# 8505    cat   6402.jpg      33     60      True
# 8740    cat   6614.jpg      50     50      True
# 10668   cat    835.jpg      60     60      True
# 13230   dog  10654.jpg      53     60      True
# 13318   dog  10733.jpg      63     42      True
# 13333   dog  10747.jpg      39     50      True
# 14376   dog  11686.jpg      48     60      True
# 15363   dog   1324.jpg      45     60      True
# 16322   dog   2188.jpg      55     60      True
# 16838   dog   2652.jpg      50     61      True
# 17185   dog   2965.jpg      50     58      True
# 22137   dog   7421.jpg      50     58      True
# 23413   dog   8570.jpg      50     60      True
# 24674   dog   9705.jpg      39     60      True

# %% [markdown]
# - We can see that there are 20 images less than 64 x 64. If we knew that the model is going to be applied for a certain image size and above we could have removed it. For now we can rely on just removing the 4 x 4 image. Instead of removing we are replacing it.

# %% [markdown]
# ##### **ScatterPlots**

# %%
from Plotter import Plotter

metadata = metadata.drop(columns=['Is_Small'])

Plotter.plot_histogram(metadata)

# %% [markdown]
# - most images have high values of width and height.
# - Most images are ~380x~500 or ~500x~500

# %% [markdown]
# #### **Network Creation**
#
# - we will be creating a very small dataset of 200, 100, 50 images respectively initially. This will save us time and once the basic setup is done we will do the same iteration on medium and then the highest dataset.

# %%
from PL3DatasetCreator import PL3DatasetCreator
datasetCreator = PL3DatasetCreator(newdirName= "Nano")
datasetCreator.createDataset(0, 200, 75, 15)

# %%
class_map = {
    "cat": "data/Nano/train/cat",
    "dog": "data/Nano/train/dog"
}
imageEdaNano = EDAImage(class_map)
image_count_Nano = imageEdaNano.get_image_counts()
metadataNano = imageEdaNano.get_image_metadata()

display(image_count_Nano)
display(metadataNano.describe())
# Out:
#   Class  ImageCount
# 0   cat         200
# 1   dog         200
#            Height       Width
# count  400.000000  400.000000
# mean   356.765000  403.050000
# std     95.646932  112.058893
# min     90.000000   80.000000
# 25%    300.000000  320.000000
# 50%    375.000000  453.000000
# 75%    400.250000  500.000000
# max    500.000000  500.000000

# %%
from tensorflow.keras.utils import image_dataset_from_directory
import pathlib


data_folder = pathlib.Path("data/Nano")
train_dataset = image_dataset_from_directory(
    data_folder / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    data_folder  / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    data_folder  / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 400 files belonging to 2 classes.
# Found 66 files belonging to 2 classes.
# Found 40 files belonging to 2 classes.

# %%
from tensorflow.keras.utils import image_dataset_from_directory
import pathlib
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from tensorflow.keras.metrics import Precision
from tensorflow.keras.metrics import Recall

from NeuralNetworkEvaluator import NeuralNetworkEvaluator
from CustomNeuralNetwork import CustomNeuralNetwork
from CustomNeuralNetwork2 import CustomNeuralNetwork2
from CustomNeuralNetwork3 import CustomNeuralNetwork3
from CustomNeuralNetwork4 import CustomNeuralNetwork4
from CustomNeuralNetwork5 import CustomNeuralNetwork5

valuator = NeuralNetworkEvaluator("data/Nano")

customNN = CustomNeuralNetwork()
customNN.model.summary()
customModel = customNN.model
valuator.trainandvalidate(customModel, "Nano", "customNN")

customNN = CustomNeuralNetwork2()
customNN.model.summary()
customModel = customNN.model
valuator.trainandvalidate(customModel, "Nano","customNN2")

customNN = CustomNeuralNetwork3()
customNN.model.summary()
customModel = customNN.model
valuator.trainandvalidate(customModel, "Nano","customNN3")

customNN = CustomNeuralNetwork4()
customNN.model.summary()
customModel = customNN.model
valuator.trainandvalidate(customModel, "Nano","customNN4")

customNN = CustomNeuralNetwork5()
customNN.model.summary()
customModel = customNN.model
valuator.trainandvalidate(customModel, "Nano","customNN5")
# Out:
# Found 400 files belonging to 2 classes.
# Found 66 files belonging to 2 classes.
# Found 40 files belonging to 2 classes.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 256)         590080
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 1)                 12545
#
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 13/13 [==============================] - 14s 938ms/step - loss: 0.7164 - accuracy: 0.5225 - auc: 0.5069 - precision: 0.5231 - recall: 0.5100 - val_loss: 0.6946 - val_accuracy: 0.5000 - val_auc: 0.3774 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 13/13 [==============================] - 12s 942ms/step - loss: 0.6930 - accuracy: 0.5150 - auc: 0.5155 - precision: 0.5375 - recall: 0.2150 - val_loss: 0.6926 - val_accuracy: 0.5000 - val_auc: 0.6028 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 3/30
# 13/13 [==============================] - 13s 954ms/step - loss: 0.6935 - accuracy: 0.4800 - auc: 0.5060 - precision: 0.4841 - recall: 0.6100 - val_loss: 0.6926 - val_accuracy: 0.5000 - val_auc: 0.5606 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 4/30
# 13/13 [==============================] - 13s 960ms/step - loss: 0.6929 - accuracy: 0.5100 - auc: 0.5290 - precision: 0.5061 - recall: 0.8350 - val_loss: 0.6939 - val_accuracy: 0.5000 - val_auc: 0.5758 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 13/13 [==============================] - 13s 957ms/step - loss: 0.6962 - accuracy: 0.4950 - auc: 0.5128 - precision: 0.4946 - recall: 0.4600 - val_loss: 0.6921 - val_accuracy: 0.5606 - val_auc: 0.6157 - val_precision: 0.5357 - val_recall: 0.9091
# Epoch 6/30
# 13/13 [==============================] - 13s 960ms/step - loss: 0.6898 - accuracy: 0.5700 - auc: 0.5725 - precision: 0.5538 - recall: 0.7200 - val_loss: 0.7800 - val_accuracy: 0.5000 - val_auc: 0.6442 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 7/30
# 13/13 [==============================] - 13s 971ms/step - loss: 0.6892 - accuracy: 0.5850 - auc: 0.6264 - precision: 0.7125 - recall: 0.2850 - val_loss: 0.6901 - val_accuracy: 0.5303 - val_auc: 0.6001 - val_precision: 0.5156 - val_recall: 1.0000
# Epoch 8/30
# 13/13 [==============================] - 13s 975ms/step - loss: 0.7034 - accuracy: 0.5725 - auc: 0.5700 - precision: 0.5736 - recall: 0.5650 - val_loss: 0.6922 - val_accuracy: 0.4848 - val_auc: 0.6318 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/30
# 13/13 [==============================] - 13s 993ms/step - loss: 0.7319 - accuracy: 0.5825 - auc: 0.6169 - precision: 0.6320 - recall: 0.3950 - val_loss: 0.6787 - val_accuracy: 0.5758 - val_auc: 0.6570 - val_precision: 0.5510 - val_recall: 0.8182
# Epoch 10/30
# 13/13 [==============================] - 13s 962ms/step - loss: 0.6591 - accuracy: 0.6350 - auc: 0.6791 - precision: 0.6174 - recall: 0.7100 - val_loss: 0.7572 - val_accuracy: 0.5000 - val_auc: 0.6175 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/30
# 13/13 [==============================] - 13s 949ms/step - loss: 0.6752 - accuracy: 0.6300 - auc: 0.6286 - precision: 0.6711 - recall: 0.5100 - val_loss: 0.6874 - val_accuracy: 0.5152 - val_auc: 0.6924 - val_precision: 0.6667 - val_recall: 0.0606
# Epoch 12/30
# 13/13 [==============================] - 13s 987ms/step - loss: 0.6210 - accuracy: 0.6675 - auc: 0.7137 - precision: 0.6872 - recall: 0.6150 - val_loss: 0.6497 - val_accuracy: 0.6061 - val_auc: 0.6460 - val_precision: 0.6296 - val_recall: 0.5152
# Epoch 13/30
# 13/13 [==============================] - 13s 969ms/step - loss: 0.6163 - accuracy: 0.6850 - auc: 0.7329 - precision: 0.7229 - recall: 0.6000 - val_loss: 0.6555 - val_accuracy: 0.5909 - val_auc: 0.6832 - val_precision: 0.7500 - val_recall: 0.2727
# Epoch 14/30
# 13/13 [==============================] - 13s 957ms/step - loss: 0.5683 - accuracy: 0.7175 - auc: 0.7757 - precision: 0.7430 - recall: 0.6650 - val_loss: 0.6464 - val_accuracy: 0.6818 - val_auc: 0.7153 - val_precision: 0.8000 - val_recall: 0.4848
# Epoch 15/30
# 13/13 [==============================] - 13s 949ms/step - loss: 0.5430 - accuracy: 0.7475 - auc: 0.8035 - precision: 0.7676 - recall: 0.7100 - val_loss: 0.7357 - val_accuracy: 0.5000 - val_auc: 0.6924 - val_precision: 0.5000 - val_recall: 0.0606
# Epoch 16/30
# 13/13 [==============================] - 13s 984ms/step - loss: 0.5486 - accuracy: 0.6950 - auc: 0.7870 - precision: 0.7267 - recall: 0.6250 - val_loss: 0.6508 - val_accuracy: 0.6061 - val_auc: 0.7291 - val_precision: 0.7333 - val_recall: 0.3333
# Epoch 17/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.4969 - accuracy: 0.7875 - auc: 0.8463 - precision: 0.8108 - recall: 0.7500 - val_loss: 0.6029 - val_accuracy: 0.6818 - val_auc: 0.7677 - val_precision: 0.7308 - val_recall: 0.5758
# Epoch 18/30
# 13/13 [==============================] - 13s 988ms/step - loss: 0.4679 - accuracy: 0.7575 - auc: 0.8496 - precision: 0.7754 - recall: 0.7250 - val_loss: 0.7014 - val_accuracy: 0.6212 - val_auc: 0.6970 - val_precision: 0.6429 - val_recall: 0.5455
# Epoch 19/30
# 13/13 [==============================] - 13s 971ms/step - loss: 0.3994 - accuracy: 0.8250 - auc: 0.9001 - precision: 0.8283 - recall: 0.8200 - val_loss: 0.6714 - val_accuracy: 0.6667 - val_auc: 0.7443 - val_precision: 0.7200 - val_recall: 0.5455
# Epoch 20/30
# 13/13 [==============================] - 13s 969ms/step - loss: 0.3585 - accuracy: 0.8225 - auc: 0.9230 - precision: 0.8274 - recall: 0.8150 - val_loss: 0.7787 - val_accuracy: 0.6212 - val_auc: 0.7332 - val_precision: 0.7222 - val_recall: 0.3939
# Epoch 21/30
# 13/13 [==============================] - 13s 979ms/step - loss: 0.3433 - accuracy: 0.8600 - auc: 0.9257 - precision: 0.8789 - recall: 0.8350 - val_loss: 0.8192 - val_accuracy: 0.6061 - val_auc: 0.6905 - val_precision: 0.6400 - val_recall: 0.4848
# Epoch 22/30
# 13/13 [==============================] - 13s 981ms/step - loss: 0.3177 - accuracy: 0.8800 - auc: 0.9425 - precision: 0.8689 - recall: 0.8950 - val_loss: 0.8537 - val_accuracy: 0.6061 - val_auc: 0.7039 - val_precision: 0.6296 - val_recall: 0.5152
# Epoch 23/30
# 13/13 [==============================] - 13s 995ms/step - loss: 0.2074 - accuracy: 0.9250 - auc: 0.9766 - precision: 0.9167 - recall: 0.9350 - val_loss: 1.1070 - val_accuracy: 0.5758 - val_auc: 0.6515 - val_precision: 0.6000 - val_recall: 0.4545
# Epoch 24/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.2280 - accuracy: 0.9125 - auc: 0.9711 - precision: 0.9104 - recall: 0.9150 - val_loss: 1.0388 - val_accuracy: 0.6061 - val_auc: 0.6882 - val_precision: 0.6296 - val_recall: 0.5152
# Epoch 25/30
# 13/13 [==============================] - 13s 962ms/step - loss: 0.1076 - accuracy: 0.9725 - auc: 0.9946 - precision: 0.9749 - recall: 0.9700 - val_loss: 1.2187 - val_accuracy: 0.6515 - val_auc: 0.7181 - val_precision: 0.6316 - val_recall: 0.7273
# Epoch 26/30
# 13/13 [==============================] - 13s 995ms/step - loss: 0.2623 - accuracy: 0.8900 - auc: 0.9594 - precision: 0.8980 - recall: 0.8800 - val_loss: 1.3310 - val_accuracy: 0.6515 - val_auc: 0.6887 - val_precision: 0.7273 - val_recall: 0.4848
# Epoch 27/30
# 13/13 [==============================] - 13s 987ms/step - loss: 0.0988 - accuracy: 0.9650 - auc: 0.9960 - precision: 0.9697 - recall: 0.9600 - val_loss: 1.1168 - val_accuracy: 0.6364 - val_auc: 0.7039 - val_precision: 0.6800 - val_recall: 0.5152
# Epoch 28/30
# 13/13 [==============================] - 13s 968ms/step - loss: 0.0296 - accuracy: 0.9975 - auc: 1.0000 - precision: 0.9950 - recall: 1.0000 - val_loss: 1.5714 - val_accuracy: 0.6515 - val_auc: 0.6786 - val_precision: 0.7273 - val_recall: 0.4848
# Epoch 29/30
# 13/13 [==============================] - 13s 964ms/step - loss: 0.0108 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.7766 - val_accuracy: 0.6061 - val_auc: 0.6786 - val_precision: 0.6400 - val_recall: 0.4848
# Epoch 30/30
# 13/13 [==============================] - 13s 963ms/step - loss: 0.2563 - accuracy: 0.9275 - auc: 0.9604 - precision: 0.9296 - recall: 0.9250 - val_loss: 1.2065 - val_accuracy: 0.6667 - val_auc: 0.7195 - val_precision: 0.7037 - val_recall: 0.5758
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_5 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_4 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 19, 19, 196)       100548
#
#  max_pooling2d_7 (MaxPooling  (None, 9, 9, 196)        0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 7, 7, 256)         451840
#
#  flatten_1 (Flatten)         (None, 12544)             0
#
#  dense_1 (Dense)             (None, 1)                 12545
#
# =================================================================
# Total params: 658,181
# Trainable params: 658,181
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 13/13 [==============================] - 14s 965ms/step - loss: 0.7880 - accuracy: 0.5225 - auc: 0.5002 - precision_1: 0.5187 - recall_1: 0.6250 - val_loss: 0.6919 - val_accuracy: 0.5000 - val_auc: 0.6575 - val_precision_1: 0.5000 - val_recall_1: 1.0000
# Epoch 2/30
# 13/13 [==============================] - 12s 919ms/step - loss: 0.6936 - accuracy: 0.5050 - auc: 0.5223 - precision_1: 0.5028 - recall_1: 0.9100 - val_loss: 0.6930 - val_accuracy: 0.5000 - val_auc: 0.4743 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/30
# 13/13 [==============================] - 12s 910ms/step - loss: 0.6941 - accuracy: 0.4925 - auc: 0.4894 - precision_1: 0.4940 - recall_1: 0.6200 - val_loss: 0.6923 - val_accuracy: 0.5152 - val_auc: 0.5909 - val_precision_1: 0.6667 - val_recall_1: 0.0606
# Epoch 4/30
# 13/13 [==============================] - 12s 878ms/step - loss: 0.6913 - accuracy: 0.5500 - auc: 0.5782 - precision_1: 0.5495 - recall_1: 0.5550 - val_loss: 0.7046 - val_accuracy: 0.5000 - val_auc: 0.4017 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/30
# 13/13 [==============================] - 12s 902ms/step - loss: 0.6958 - accuracy: 0.5225 - auc: 0.5085 - precision_1: 0.5246 - recall_1: 0.4800 - val_loss: 0.6893 - val_accuracy: 0.5000 - val_auc: 0.6915 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/30
# 13/13 [==============================] - 13s 1s/step - loss: 0.6890 - accuracy: 0.5125 - auc: 0.5537 - precision_1: 0.5141 - recall_1: 0.4550 - val_loss: 0.6865 - val_accuracy: 0.5152 - val_auc: 0.6947 - val_precision_1: 0.5077 - val_recall_1: 1.0000
# Epoch 7/30
# 13/13 [==============================] - 12s 871ms/step - loss: 0.7404 - accuracy: 0.5475 - auc: 0.5943 - precision_1: 0.5543 - recall_1: 0.4850 - val_loss: 0.6842 - val_accuracy: 0.6061 - val_auc: 0.6602 - val_precision_1: 0.6667 - val_recall_1: 0.4242
# Epoch 8/30
# 13/13 [==============================] - 13s 989ms/step - loss: 0.6760 - accuracy: 0.5725 - auc: 0.6211 - precision_1: 0.5767 - recall_1: 0.5450 - val_loss: 0.6823 - val_accuracy: 0.6061 - val_auc: 0.5973 - val_precision_1: 0.6842 - val_recall_1: 0.3939
# Epoch 9/30
# 13/13 [==============================] - 13s 913ms/step - loss: 0.6750 - accuracy: 0.5825 - auc: 0.6222 - precision_1: 0.5954 - recall_1: 0.5150 - val_loss: 0.6771 - val_accuracy: 0.6061 - val_auc: 0.7006 - val_precision_1: 0.5636 - val_recall_1: 0.9394
# Epoch 10/30
# 13/13 [==============================] - 13s 1s/step - loss: 0.6522 - accuracy: 0.6325 - auc: 0.6768 - precision_1: 0.6256 - recall_1: 0.6600 - val_loss: 0.6603 - val_accuracy: 0.5606 - val_auc: 0.6717 - val_precision_1: 0.6429 - val_recall_1: 0.2727
# Epoch 11/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6317 - accuracy: 0.6625 - auc: 0.6991 - precision_1: 0.6617 - recall_1: 0.6650 - val_loss: 0.6519 - val_accuracy: 0.5909 - val_auc: 0.6979 - val_precision_1: 0.7500 - val_recall_1: 0.2727
# Epoch 12/30
# 13/13 [==============================] - 12s 944ms/step - loss: 0.6608 - accuracy: 0.6350 - auc: 0.6857 - precision_1: 0.6687 - recall_1: 0.5350 - val_loss: 0.6363 - val_accuracy: 0.6515 - val_auc: 0.7089 - val_precision_1: 0.6923 - val_recall_1: 0.5455
# Epoch 13/30
# 13/13 [==============================] - 13s 961ms/step - loss: 0.6866 - accuracy: 0.6900 - auc: 0.7188 - precision_1: 0.7088 - recall_1: 0.6450 - val_loss: 0.6532 - val_accuracy: 0.6061 - val_auc: 0.6942 - val_precision_1: 0.6842 - val_recall_1: 0.3939
# Epoch 14/30
# 13/13 [==============================] - 11s 842ms/step - loss: 0.5707 - accuracy: 0.7150 - auc: 0.7948 - precision_1: 0.7287 - recall_1: 0.6850 - val_loss: 0.6405 - val_accuracy: 0.5758 - val_auc: 0.7406 - val_precision_1: 0.6471 - val_recall_1: 0.3333
# Epoch 15/30
# 13/13 [==============================] - 11s 859ms/step - loss: 0.5444 - accuracy: 0.7375 - auc: 0.7961 - precision_1: 0.7624 - recall_1: 0.6900 - val_loss: 0.7720 - val_accuracy: 0.5303 - val_auc: 0.6143 - val_precision_1: 0.5833 - val_recall_1: 0.2121
# Epoch 16/30
# 13/13 [==============================] - 11s 844ms/step - loss: 0.5133 - accuracy: 0.7275 - auc: 0.8224 - precision_1: 0.7264 - recall_1: 0.7300 - val_loss: 0.7645 - val_accuracy: 0.5152 - val_auc: 0.6786 - val_precision_1: 0.5714 - val_recall_1: 0.1212
# Epoch 17/30
# 13/13 [==============================] - 11s 858ms/step - loss: 0.5289 - accuracy: 0.7475 - auc: 0.8134 - precision_1: 0.7619 - recall_1: 0.7200 - val_loss: 0.8462 - val_accuracy: 0.5152 - val_auc: 0.7084 - val_precision_1: 0.6000 - val_recall_1: 0.0909
# Epoch 18/30
# 13/13 [==============================] - 11s 851ms/step - loss: 0.4636 - accuracy: 0.7700 - auc: 0.8589 - precision_1: 0.8000 - recall_1: 0.7200 - val_loss: 0.7177 - val_accuracy: 0.7273 - val_auc: 0.7727 - val_precision_1: 0.6667 - val_recall_1: 0.9091
# Epoch 19/30
# 13/13 [==============================] - 11s 846ms/step - loss: 0.4204 - accuracy: 0.8175 - auc: 0.8892 - precision_1: 0.8223 - recall_1: 0.8100 - val_loss: 0.6306 - val_accuracy: 0.7121 - val_auc: 0.7686 - val_precision_1: 0.7188 - val_recall_1: 0.6970
# Epoch 20/30
# 13/13 [==============================] - 12s 871ms/step - loss: 0.3535 - accuracy: 0.8425 - auc: 0.9218 - precision_1: 0.8549 - recall_1: 0.8250 - val_loss: 0.7578 - val_accuracy: 0.6212 - val_auc: 0.7080 - val_precision_1: 0.7500 - val_recall_1: 0.3636
# Epoch 21/30
# 13/13 [==============================] - 12s 889ms/step - loss: 0.3283 - accuracy: 0.8750 - auc: 0.9410 - precision_1: 0.8866 - recall_1: 0.8600 - val_loss: 0.6678 - val_accuracy: 0.7273 - val_auc: 0.7585 - val_precision_1: 0.7143 - val_recall_1: 0.7576
# Epoch 22/30
# 13/13 [==============================] - 12s 888ms/step - loss: 0.2784 - accuracy: 0.8950 - auc: 0.9584 - precision_1: 0.8835 - recall_1: 0.9100 - val_loss: 0.7616 - val_accuracy: 0.6364 - val_auc: 0.7080 - val_precision_1: 0.6286 - val_recall_1: 0.6667
# Epoch 23/30
# 13/13 [==============================] - 12s 916ms/step - loss: 0.2513 - accuracy: 0.9000 - auc: 0.9638 - precision_1: 0.8922 - recall_1: 0.9100 - val_loss: 0.9099 - val_accuracy: 0.6970 - val_auc: 0.7057 - val_precision_1: 0.7600 - val_recall_1: 0.5758
# Epoch 24/30
# 13/13 [==============================] - 13s 974ms/step - loss: 0.2483 - accuracy: 0.8975 - auc: 0.9624 - precision_1: 0.9162 - recall_1: 0.8750 - val_loss: 0.9308 - val_accuracy: 0.6970 - val_auc: 0.7410 - val_precision_1: 0.7097 - val_recall_1: 0.6667
# Epoch 25/30
# 13/13 [==============================] - 12s 929ms/step - loss: 0.1384 - accuracy: 0.9575 - auc: 0.9896 - precision_1: 0.9463 - recall_1: 0.9700 - val_loss: 1.0420 - val_accuracy: 0.7121 - val_auc: 0.7222 - val_precision_1: 0.7059 - val_recall_1: 0.7273
# Epoch 26/30
# 13/13 [==============================] - 12s 892ms/step - loss: 0.1197 - accuracy: 0.9575 - auc: 0.9924 - precision_1: 0.9420 - recall_1: 0.9750 - val_loss: 1.5169 - val_accuracy: 0.4848 - val_auc: 0.5950 - val_precision_1: 0.3333 - val_recall_1: 0.0303
# Epoch 27/30
# 13/13 [==============================] - 12s 903ms/step - loss: 0.1335 - accuracy: 0.9525 - auc: 0.9904 - precision_1: 0.9641 - recall_1: 0.9400 - val_loss: 1.1242 - val_accuracy: 0.6970 - val_auc: 0.7319 - val_precision_1: 0.7241 - val_recall_1: 0.6364
# Epoch 28/30
# 13/13 [==============================] - 12s 915ms/step - loss: 0.0556 - accuracy: 0.9875 - auc: 0.9983 - precision_1: 0.9851 - recall_1: 0.9900 - val_loss: 1.9706 - val_accuracy: 0.6818 - val_auc: 0.7346 - val_precision_1: 0.6429 - val_recall_1: 0.8182
# Epoch 29/30
# 13/13 [==============================] - 12s 887ms/step - loss: 0.1408 - accuracy: 0.9425 - auc: 0.9881 - precision_1: 0.9360 - recall_1: 0.9500 - val_loss: 1.4573 - val_accuracy: 0.6818 - val_auc: 0.7213 - val_precision_1: 0.7143 - val_recall_1: 0.6061
# Epoch 30/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.0255 - accuracy: 0.9950 - auc: 0.9999 - precision_1: 0.9950 - recall_1: 0.9950 - val_loss: 1.8270 - val_accuracy: 0.6667 - val_auc: 0.6690 - val_precision_1: 0.6571 - val_recall_1: 0.6970
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_10 (Conv2D)          (None, 178, 178, 32)      896
#
#  max_pooling2d_8 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 41, 41, 128)       73856
#
#  max_pooling2d_10 (MaxPoolin  (None, 20, 20, 128)      0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 196)       627396
#
#  max_pooling2d_11 (MaxPoolin  (None, 8, 8, 196)        0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 6, 6, 256)         451840
#
#  flatten_2 (Flatten)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 1)                 9217
#
# =================================================================
# Total params: 1,181,701
# Trainable params: 1,181,701
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 13/13 [==============================] - 18s 1s/step - loss: 0.7160 - accuracy: 0.4925 - auc: 0.4425 - precision_2: 0.4955 - recall_2: 0.8250 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6933 - accuracy: 0.5025 - auc: 0.4704 - precision_2: 0.5044 - recall_2: 0.2850 - val_loss: 0.6928 - val_accuracy: 0.5000 - val_auc: 0.5758 - val_precision_2: 0.5000 - val_recall_2: 1.0000
# Epoch 3/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6935 - accuracy: 0.4900 - auc: 0.4821 - precision_2: 0.4932 - recall_2: 0.7250 - val_loss: 0.6930 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6949 - accuracy: 0.5200 - auc: 0.5367 - precision_2: 0.5278 - recall_2: 0.3800 - val_loss: 0.6929 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6934 - accuracy: 0.5075 - auc: 0.4864 - precision_2: 0.5118 - recall_2: 0.3250 - val_loss: 0.6926 - val_accuracy: 0.5606 - val_auc: 0.5390 - val_precision_2: 1.0000 - val_recall_2: 0.1212
# Epoch 6/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6901 - accuracy: 0.5775 - auc: 0.5868 - precision_2: 0.5939 - recall_2: 0.4900 - val_loss: 0.6919 - val_accuracy: 0.4697 - val_auc: 0.5684 - val_precision_2: 0.4783 - val_recall_2: 0.6667
# Epoch 7/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6907 - accuracy: 0.5825 - auc: 0.5877 - precision_2: 0.6222 - recall_2: 0.4200 - val_loss: 0.6926 - val_accuracy: 0.5000 - val_auc: 0.5707 - val_precision_2: 0.5000 - val_recall_2: 1.0000
# Epoch 8/30
# 13/13 [==============================] - 16s 1s/step - loss: 0.6881 - accuracy: 0.5425 - auc: 0.5661 - precision_2: 0.5347 - recall_2: 0.6550 - val_loss: 0.6913 - val_accuracy: 0.5455 - val_auc: 0.5427 - val_precision_2: 0.5652 - val_recall_2: 0.3939
# Epoch 9/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.7064 - accuracy: 0.6200 - auc: 0.6599 - precision_2: 0.6101 - recall_2: 0.6650 - val_loss: 0.7831 - val_accuracy: 0.5000 - val_auc: 0.5005 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 10/30
# 13/13 [==============================] - 16s 1s/step - loss: 0.6554 - accuracy: 0.6250 - auc: 0.6715 - precision_2: 0.7083 - recall_2: 0.4250 - val_loss: 0.7053 - val_accuracy: 0.4848 - val_auc: 0.5161 - val_precision_2: 0.4878 - val_recall_2: 0.6061
# Epoch 11/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6310 - accuracy: 0.6175 - auc: 0.6948 - precision_2: 0.6181 - recall_2: 0.6150 - val_loss: 0.7508 - val_accuracy: 0.4848 - val_auc: 0.5432 - val_precision_2: 0.4902 - val_recall_2: 0.7576
# Epoch 12/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6062 - accuracy: 0.6825 - auc: 0.7318 - precision_2: 0.6872 - recall_2: 0.6700 - val_loss: 1.0917 - val_accuracy: 0.5152 - val_auc: 0.5739 - val_precision_2: 0.6667 - val_recall_2: 0.0606
# Epoch 13/30
# 13/13 [==============================] - 16s 1s/step - loss: 0.6563 - accuracy: 0.6525 - auc: 0.6912 - precision_2: 0.6968 - recall_2: 0.5400 - val_loss: 0.6578 - val_accuracy: 0.5152 - val_auc: 0.6345 - val_precision_2: 0.5238 - val_recall_2: 0.3333
# Epoch 14/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.5992 - accuracy: 0.6700 - auc: 0.7466 - precision_2: 0.6889 - recall_2: 0.6200 - val_loss: 0.7266 - val_accuracy: 0.5455 - val_auc: 0.5253 - val_precision_2: 0.5882 - val_recall_2: 0.3030
# Epoch 15/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.5458 - accuracy: 0.7300 - auc: 0.7982 - precision_2: 0.7500 - recall_2: 0.6900 - val_loss: 0.7625 - val_accuracy: 0.5152 - val_auc: 0.5670 - val_precision_2: 0.5102 - val_recall_2: 0.7576
# Epoch 16/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.5534 - accuracy: 0.7075 - auc: 0.7875 - precision_2: 0.6967 - recall_2: 0.7350 - val_loss: 0.7358 - val_accuracy: 0.5455 - val_auc: 0.5799 - val_precision_2: 0.5385 - val_recall_2: 0.6364
# Epoch 17/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.4790 - accuracy: 0.7700 - auc: 0.8549 - precision_2: 0.7842 - recall_2: 0.7450 - val_loss: 1.3101 - val_accuracy: 0.5152 - val_auc: 0.6019 - val_precision_2: 0.5714 - val_recall_2: 0.1212
# Epoch 18/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.4947 - accuracy: 0.7750 - auc: 0.8427 - precision_2: 0.7835 - recall_2: 0.7600 - val_loss: 0.7425 - val_accuracy: 0.5909 - val_auc: 0.6419 - val_precision_2: 0.5938 - val_recall_2: 0.5758
# Epoch 19/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.4268 - accuracy: 0.7875 - auc: 0.8862 - precision_2: 0.8010 - recall_2: 0.7650 - val_loss: 0.8824 - val_accuracy: 0.6212 - val_auc: 0.6364 - val_precision_2: 0.6111 - val_recall_2: 0.6667
# Epoch 20/30
# 13/13 [==============================] - 16s 1s/step - loss: 0.4079 - accuracy: 0.8125 - auc: 0.8972 - precision_2: 0.8019 - recall_2: 0.8300 - val_loss: 1.1309 - val_accuracy: 0.5758 - val_auc: 0.6157 - val_precision_2: 0.5714 - val_recall_2: 0.6061
# Epoch 21/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.4077 - accuracy: 0.8425 - auc: 0.9146 - precision_2: 0.8374 - recall_2: 0.8500 - val_loss: 0.9717 - val_accuracy: 0.5909 - val_auc: 0.6419 - val_precision_2: 0.5882 - val_recall_2: 0.6061
# Epoch 22/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.3097 - accuracy: 0.8600 - auc: 0.9433 - precision_2: 0.8462 - recall_2: 0.8800 - val_loss: 1.5127 - val_accuracy: 0.5455 - val_auc: 0.5317 - val_precision_2: 0.6364 - val_recall_2: 0.2121
# Epoch 23/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.3139 - accuracy: 0.8525 - auc: 0.9397 - precision_2: 0.8543 - recall_2: 0.8500 - val_loss: 1.1898 - val_accuracy: 0.5606 - val_auc: 0.6185 - val_precision_2: 0.6429 - val_recall_2: 0.2727
# Epoch 24/30
# 13/13 [==============================] - 17s 1s/step - loss: 0.2403 - accuracy: 0.8975 - auc: 0.9668 - precision_2: 0.9036 - recall_2: 0.8900 - val_loss: 1.1255 - val_accuracy: 0.5455 - val_auc: 0.6028 - val_precision_2: 0.5517 - val_recall_2: 0.4848
# Epoch 25/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.2156 - accuracy: 0.9075 - auc: 0.9727 - precision_2: 0.8937 - recall_2: 0.9250 - val_loss: 1.4150 - val_accuracy: 0.5909 - val_auc: 0.6814 - val_precision_2: 0.6154 - val_recall_2: 0.4848
# Epoch 26/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.1642 - accuracy: 0.9475 - auc: 0.9821 - precision_2: 0.9590 - recall_2: 0.9350 - val_loss: 1.6287 - val_accuracy: 0.5606 - val_auc: 0.5482 - val_precision_2: 0.5625 - val_recall_2: 0.5455
# Epoch 27/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.1730 - accuracy: 0.9400 - auc: 0.9839 - precision_2: 0.9356 - recall_2: 0.9450 - val_loss: 1.4953 - val_accuracy: 0.5303 - val_auc: 0.5877 - val_precision_2: 0.5556 - val_recall_2: 0.3030
# Epoch 28/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.1141 - accuracy: 0.9475 - auc: 0.9928 - precision_2: 0.9409 - recall_2: 0.9550 - val_loss: 1.4176 - val_accuracy: 0.6364 - val_auc: 0.7172 - val_precision_2: 0.7143 - val_recall_2: 0.4545
# Epoch 29/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.0420 - accuracy: 0.9950 - auc: 0.9998 - precision_2: 0.9950 - recall_2: 0.9950 - val_loss: 1.8275 - val_accuracy: 0.7121 - val_auc: 0.7507 - val_precision_2: 0.7500 - val_recall_2: 0.6364
# Epoch 30/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.1880 - accuracy: 0.9475 - auc: 0.9763 - precision_2: 0.9497 - recall_2: 0.9450 - val_loss: 1.3941 - val_accuracy: 0.6515 - val_auc: 0.6882 - val_precision_2: 0.6667 - val_recall_2: 0.6061
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_15 (Conv2D)          (None, 178, 178, 32)      896
#
#  max_pooling2d_12 (MaxPoolin  (None, 89, 89, 32)       0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 43, 43, 64)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 41, 41, 128)       73856
#
#  max_pooling2d_14 (MaxPoolin  (None, 20, 20, 128)      0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 18, 18, 256)       295168
#
#  max_pooling2d_15 (MaxPoolin  (None, 9, 9, 256)        0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 7, 7, 256)         590080
#
#  flatten_3 (Flatten)         (None, 12544)             0
#
#  dense_3 (Dense)             (None, 10)                125450
#
#  dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1,103,957
# Trainable params: 1,103,957
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 13/13 [==============================] - 16s 1s/step - loss: 1.0994 - accuracy: 0.5225 - auc: 0.4950 - precision_3: 0.5556 - recall_3: 0.2250 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_auc: 0.5152 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6935 - accuracy: 0.4800 - auc: 0.4875 - precision_3: 0.4683 - recall_3: 0.2950 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6931 - accuracy: 0.4700 - auc: 0.5075 - precision_3: 0.4750 - recall_3: 0.5700 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6932 - accuracy: 0.5000 - auc: 0.5000 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 0.6931 - val_accuracy: 0.5758 - val_auc: 0.5000 - val_precision_3: 0.6667 - val_recall_3: 0.3030
# Epoch 5/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6932 - accuracy: 0.5050 - auc: 0.5000 - precision_3: 0.7500 - recall_3: 0.0150 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_3: 0.5000 - val_recall_3: 1.0000
# Epoch 6/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6932 - accuracy: 0.5025 - auc: 0.5000 - precision_3: 0.5013 - recall_3: 1.0000 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_3: 0.5000 - val_recall_3: 1.0000
# Epoch 7/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6932 - accuracy: 0.4875 - auc: 0.5000 - precision_3: 0.4917 - recall_3: 0.7400 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_3: 0.5000 - val_recall_3: 1.0000
# Epoch 8/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6932 - accuracy: 0.4800 - auc: 0.5000 - precision_3: 0.4851 - recall_3: 0.6500 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_3: 0.5000 - val_recall_3: 1.0000
# Epoch 9/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6931 - accuracy: 0.4900 - auc: 0.5000 - precision_3: 0.4938 - recall_3: 0.7950 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_3: 0.5000 - val_recall_3: 1.0000
# Epoch 10/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6932 - accuracy: 0.4800 - auc: 0.4825 - precision_3: 0.4775 - recall_3: 0.4250 - val_loss: 0.6931 - val_accuracy: 0.4848 - val_auc: 0.5000 - val_precision_3: 0.4921 - val_recall_3: 0.9394
# Epoch 11/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6931 - accuracy: 0.5100 - auc: 0.5000 - precision_3: 0.5052 - recall_3: 0.9800 - val_loss: 0.6931 - val_accuracy: 0.5455 - val_auc: 0.5000 - val_precision_3: 0.5319 - val_recall_3: 0.7576
# Epoch 12/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6931 - accuracy: 0.5225 - auc: 0.5000 - precision_3: 0.5226 - recall_3: 0.5200 - val_loss: 0.6930 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_3: 0.5000 - val_recall_3: 1.0000
# Epoch 13/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6931 - accuracy: 0.4950 - auc: 0.4975 - precision_3: 0.4971 - recall_3: 0.8700 - val_loss: 0.6931 - val_accuracy: 0.6212 - val_auc: 0.5000 - val_precision_3: 0.6818 - val_recall_3: 0.4545
# Epoch 14/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6931 - accuracy: 0.5250 - auc: 0.5265 - precision_3: 0.5135 - recall_3: 0.9500 - val_loss: 0.6931 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 15/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6929 - accuracy: 0.4900 - auc: 0.5275 - precision_3: 0.4940 - recall_3: 0.8200 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 16/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6942 - accuracy: 0.5250 - auc: 0.4865 - precision_3: 0.5236 - recall_3: 0.5550 - val_loss: 0.6928 - val_accuracy: 0.5606 - val_auc: 0.5303 - val_precision_3: 0.7500 - val_recall_3: 0.1818
# Epoch 17/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6936 - accuracy: 0.5200 - auc: 0.4808 - precision_3: 0.5571 - recall_3: 0.1950 - val_loss: 0.6930 - val_accuracy: 0.5000 - val_auc: 0.5455 - val_precision_3: 0.5000 - val_recall_3: 0.8182
# Epoch 18/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6925 - accuracy: 0.5250 - auc: 0.5449 - precision_3: 0.5191 - recall_3: 0.6800 - val_loss: 0.6929 - val_accuracy: 0.5000 - val_auc: 0.5165 - val_precision_3: 0.5000 - val_recall_3: 0.3636
# Epoch 19/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6954 - accuracy: 0.5425 - auc: 0.5388 - precision_3: 0.5326 - recall_3: 0.6950 - val_loss: 0.6946 - val_accuracy: 0.5000 - val_auc: 0.5009 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 20/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6910 - accuracy: 0.4950 - auc: 0.5381 - precision_3: 0.4967 - recall_3: 0.7550 - val_loss: 0.6928 - val_accuracy: 0.4697 - val_auc: 0.4986 - val_precision_3: 0.4839 - val_recall_3: 0.9091
# Epoch 21/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6875 - accuracy: 0.5775 - auc: 0.5913 - precision_3: 0.5928 - recall_3: 0.4950 - val_loss: 0.6944 - val_accuracy: 0.5152 - val_auc: 0.5156 - val_precision_3: 0.5106 - val_recall_3: 0.7273
# Epoch 22/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6928 - accuracy: 0.6050 - auc: 0.6168 - precision_3: 0.6313 - recall_3: 0.5050 - val_loss: 0.6965 - val_accuracy: 0.4848 - val_auc: 0.5335 - val_precision_3: 0.4921 - val_recall_3: 0.9394
# Epoch 23/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6808 - accuracy: 0.6100 - auc: 0.6416 - precision_3: 0.5948 - recall_3: 0.6900 - val_loss: 0.7112 - val_accuracy: 0.5000 - val_auc: 0.5174 - val_precision_3: 0.5000 - val_recall_3: 0.0909
# Epoch 24/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6558 - accuracy: 0.6000 - auc: 0.6659 - precision_3: 0.6136 - recall_3: 0.5400 - val_loss: 0.6966 - val_accuracy: 0.5303 - val_auc: 0.5891 - val_precision_3: 0.5161 - val_recall_3: 0.9697
# Epoch 25/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6509 - accuracy: 0.6275 - auc: 0.6824 - precision_3: 0.6154 - recall_3: 0.6800 - val_loss: 0.8722 - val_accuracy: 0.5152 - val_auc: 0.6166 - val_precision_3: 0.5077 - val_recall_3: 1.0000
# Epoch 26/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6541 - accuracy: 0.6150 - auc: 0.6704 - precision_3: 0.6075 - recall_3: 0.6500 - val_loss: 0.7193 - val_accuracy: 0.5303 - val_auc: 0.5643 - val_precision_3: 0.5556 - val_recall_3: 0.3030
# Epoch 27/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6358 - accuracy: 0.6325 - auc: 0.6977 - precision_3: 0.6305 - recall_3: 0.6400 - val_loss: 0.6840 - val_accuracy: 0.5909 - val_auc: 0.6088 - val_precision_3: 0.5833 - val_recall_3: 0.6364
# Epoch 28/30
# 13/13 [==============================] - 14s 1s/step - loss: 0.6218 - accuracy: 0.6775 - auc: 0.7155 - precision_3: 0.6898 - recall_3: 0.6450 - val_loss: 0.7274 - val_accuracy: 0.5303 - val_auc: 0.5404 - val_precision_3: 0.5385 - val_recall_3: 0.4242
# Epoch 29/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.5971 - accuracy: 0.7025 - auc: 0.7603 - precision_3: 0.7143 - recall_3: 0.6750 - val_loss: 0.6529 - val_accuracy: 0.6212 - val_auc: 0.7323 - val_precision_3: 0.5870 - val_recall_3: 0.8182
# Epoch 30/30
# 13/13 [==============================] - 15s 1s/step - loss: 0.6006 - accuracy: 0.6775 - auc: 0.7438 - precision_3: 0.6839 - recall_3: 0.6600 - val_loss: 0.6904 - val_accuracy: 0.5606 - val_auc: 0.6129 - val_precision_3: 0.5714 - val_recall_3: 0.4848
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling_4 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_20 (Conv2D)          (None, 178, 178, 128)     3584
#
#  max_pooling2d_16 (MaxPoolin  (None, 89, 89, 128)      0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 87, 87, 32)        36896
#
#  max_pooling2d_17 (MaxPoolin  (None, 43, 43, 32)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 41, 41, 64)        18496
#
#  max_pooling2d_18 (MaxPoolin  (None, 20, 20, 64)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 18, 18, 128)       73856
#
#  max_pooling2d_19 (MaxPoolin  (None, 9, 9, 128)        0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 7, 7, 256)         295168
#
#  max_pooling2d_20 (MaxPoolin  (None, 3, 3, 256)        0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 1, 1, 256)         590080
#
#  flatten_4 (Flatten)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 1,018,337
# Trainable params: 1,018,337
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 13/13 [==============================] - 29s 2s/step - loss: 0.7486 - accuracy: 0.4800 - auc: 0.4532 - precision_4: 0.4600 - recall_4: 0.2300 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/30
# 13/13 [==============================] - 25s 2s/step - loss: 0.6933 - accuracy: 0.5275 - auc: 0.4950 - precision_4: 0.6486 - recall_4: 0.1200 - val_loss: 0.6934 - val_accuracy: 0.5000 - val_auc: 0.5152 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/30
# 13/13 [==============================] - 27s 2s/step - loss: 0.6936 - accuracy: 0.5000 - auc: 0.4903 - precision_4: 0.5000 - recall_4: 0.2750 - val_loss: 0.6928 - val_accuracy: 0.5455 - val_auc: 0.4848 - val_precision_4: 0.5789 - val_recall_4: 0.3333
# Epoch 4/30
# 13/13 [==============================] - 25s 2s/step - loss: 0.6934 - accuracy: 0.5275 - auc: 0.4943 - precision_4: 0.5647 - recall_4: 0.2400 - val_loss: 0.6924 - val_accuracy: 0.5000 - val_auc: 0.5996 - val_precision_4: 0.5000 - val_recall_4: 1.0000
# Epoch 5/30
# 13/13 [==============================] - 24s 2s/step - loss: 0.6961 - accuracy: 0.4975 - auc: 0.5032 - precision_4: 0.4984 - recall_4: 0.7900 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_auc: 0.4697 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 6/30
# 13/13 [==============================] - 21s 2s/step - loss: 0.6931 - accuracy: 0.5125 - auc: 0.5086 - precision_4: 0.5269 - recall_4: 0.2450 - val_loss: 0.6923 - val_accuracy: 0.5303 - val_auc: 0.5863 - val_precision_4: 0.7500 - val_recall_4: 0.0909
# Epoch 7/30
# 13/13 [==============================] - 21s 2s/step - loss: 0.6917 - accuracy: 0.5450 - auc: 0.5527 - precision_4: 0.5634 - recall_4: 0.4000 - val_loss: 0.6922 - val_accuracy: 0.5000 - val_auc: 0.5960 - val_precision_4: 0.5000 - val_recall_4: 1.0000
# Epoch 8/30
# 13/13 [==============================] - 22s 2s/step - loss: 0.6991 - accuracy: 0.5100 - auc: 0.4959 - precision_4: 0.5125 - recall_4: 0.4100 - val_loss: 0.6909 - val_accuracy: 0.6515 - val_auc: 0.6180 - val_precision_4: 0.6136 - val_recall_4: 0.8182
# Epoch 9/30
# 13/13 [==============================] - 21s 2s/step - loss: 0.6951 - accuracy: 0.4950 - auc: 0.5040 - precision_4: 0.4962 - recall_4: 0.6600 - val_loss: 0.6927 - val_accuracy: 0.5000 - val_auc: 0.5147 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 10/30
# 13/13 [==============================] - 21s 2s/step - loss: 0.6940 - accuracy: 0.4925 - auc: 0.5069 - precision_4: 0.4444 - recall_4: 0.0600 - val_loss: 0.6928 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 11/30
# 13/13 [==============================] - 21s 2s/step - loss: 0.6910 - accuracy: 0.5325 - auc: 0.5615 - precision_4: 0.5607 - recall_4: 0.3000 - val_loss: 0.7111 - val_accuracy: 0.5000 - val_auc: 0.6648 - val_precision_4: 0.5000 - val_recall_4: 1.0000
# Epoch 12/30
# 13/13 [==============================] - 21s 2s/step - loss: 0.6991 - accuracy: 0.4900 - auc: 0.4808 - precision_4: 0.4932 - recall_4: 0.7250 - val_loss: 0.6911 - val_accuracy: 0.5606 - val_auc: 0.5767 - val_precision_4: 0.6111 - val_recall_4: 0.3333
# Epoch 13/30
# 13/13 [==============================] - 21s 2s/step - loss: 0.6935 - accuracy: 0.5050 - auc: 0.5130 - precision_4: 0.5034 - recall_4: 0.7300 - val_loss: 0.6917 - val_accuracy: 0.5303 - val_auc: 0.5767 - val_precision_4: 0.5167 - val_recall_4: 0.9394
# Epoch 14/30
# 13/13 [==============================] - 23s 2s/step - loss: 0.6919 - accuracy: 0.5700 - auc: 0.5712 - precision_4: 0.5614 - recall_4: 0.6400 - val_loss: 0.6875 - val_accuracy: 0.5455 - val_auc: 0.7039 - val_precision_4: 0.8000 - val_recall_4: 0.1212
# Epoch 15/30
# 13/13 [==============================] - 21s 2s/step - loss: 0.6916 - accuracy: 0.5225 - auc: 0.5185 - precision_4: 0.5179 - recall_4: 0.6500 - val_loss: 0.6902 - val_accuracy: 0.5606 - val_auc: 0.5601 - val_precision_4: 0.6667 - val_recall_4: 0.2424
# Epoch 16/30
# 13/13 [==============================] - 21s 2s/step - loss: 0.6889 - accuracy: 0.5575 - auc: 0.5778 - precision_4: 0.5697 - recall_4: 0.4700 - val_loss: 0.6943 - val_accuracy: 0.5152 - val_auc: 0.5294 - val_precision_4: 0.5714 - val_recall_4: 0.1212
# Epoch 17/30
# 13/13 [==============================] - 22s 2s/step - loss: 0.6862 - accuracy: 0.5500 - auc: 0.5760 - precision_4: 0.5455 - recall_4: 0.6000 - val_loss: 0.6885 - val_accuracy: 0.5303 - val_auc: 0.5615 - val_precision_4: 0.5357 - val_recall_4: 0.4545
# Epoch 18/30
# 13/13 [==============================] - 22s 2s/step - loss: 0.6953 - accuracy: 0.5675 - auc: 0.5863 - precision_4: 0.5570 - recall_4: 0.6600 - val_loss: 0.6902 - val_accuracy: 0.5152 - val_auc: 0.6157 - val_precision_4: 0.5079 - val_recall_4: 0.9697
# Epoch 19/30
# 13/13 [==============================] - 22s 2s/step - loss: 0.6882 - accuracy: 0.5750 - auc: 0.5825 - precision_4: 0.5610 - recall_4: 0.6900 - val_loss: 0.6794 - val_accuracy: 0.5303 - val_auc: 0.6965 - val_precision_4: 0.5161 - val_recall_4: 0.9697
# Epoch 20/30
# 13/13 [==============================] - 22s 2s/step - loss: 0.6701 - accuracy: 0.5900 - auc: 0.6231 - precision_4: 0.5776 - recall_4: 0.6700 - val_loss: 0.6985 - val_accuracy: 0.5606 - val_auc: 0.5601 - val_precision_4: 0.6000 - val_recall_4: 0.3636
# Epoch 21/30
# 13/13 [==============================] - 23s 2s/step - loss: 0.6625 - accuracy: 0.5625 - auc: 0.6275 - precision_4: 0.5510 - recall_4: 0.6750 - val_loss: 0.6667 - val_accuracy: 0.5909 - val_auc: 0.6570 - val_precision_4: 0.5652 - val_recall_4: 0.7879
# Epoch 22/30
# 13/13 [==============================] - 23s 2s/step - loss: 0.6586 - accuracy: 0.6225 - auc: 0.6769 - precision_4: 0.6129 - recall_4: 0.6650 - val_loss: 0.6706 - val_accuracy: 0.6061 - val_auc: 0.6400 - val_precision_4: 0.6207 - val_recall_4: 0.5455
# Epoch 23/30
# 13/13 [==============================] - 22s 2s/step - loss: 0.6637 - accuracy: 0.6275 - auc: 0.6512 - precision_4: 0.6294 - recall_4: 0.6200 - val_loss: 0.6764 - val_accuracy: 0.5303 - val_auc: 0.6938 - val_precision_4: 0.5167 - val_recall_4: 0.9394
# Epoch 24/30
# 13/13 [==============================] - 22s 2s/step - loss: 0.6270 - accuracy: 0.6750 - auc: 0.7018 - precision_4: 0.6496 - recall_4: 0.7600 - val_loss: 0.7271 - val_accuracy: 0.5152 - val_auc: 0.6107 - val_precision_4: 0.5079 - val_recall_4: 0.9697
# Epoch 25/30
# 13/13 [==============================] - 22s 2s/step - loss: 0.6107 - accuracy: 0.6525 - auc: 0.7223 - precision_4: 0.6187 - recall_4: 0.7950 - val_loss: 0.9897 - val_accuracy: 0.5152 - val_auc: 0.6299 - val_precision_4: 0.5077 - val_recall_4: 1.0000
# Epoch 26/30
# 13/13 [==============================] - 22s 2s/step - loss: 0.5981 - accuracy: 0.6875 - auc: 0.7424 - precision_4: 0.6582 - recall_4: 0.7800 - val_loss: 0.6328 - val_accuracy: 0.7273 - val_auc: 0.7557 - val_precision_4: 0.6744 - val_recall_4: 0.8788
# Epoch 27/30
# 13/13 [==============================] - 23s 2s/step - loss: 0.5707 - accuracy: 0.7150 - auc: 0.7736 - precision_4: 0.6838 - recall_4: 0.8000 - val_loss: 0.7351 - val_accuracy: 0.5152 - val_auc: 0.5771 - val_precision_4: 0.5294 - val_recall_4: 0.2727
# Epoch 28/30
# 13/13 [==============================] - 23s 2s/step - loss: 0.5869 - accuracy: 0.7125 - auc: 0.7695 - precision_4: 0.7179 - recall_4: 0.7000 - val_loss: 0.7286 - val_accuracy: 0.6061 - val_auc: 0.7337 - val_precision_4: 0.5636 - val_recall_4: 0.9394
# Epoch 29/30
# 13/13 [==============================] - 21s 2s/step - loss: 0.5366 - accuracy: 0.7150 - auc: 0.8077 - precision_4: 0.7009 - recall_4: 0.7500 - val_loss: 0.6703 - val_accuracy: 0.6515 - val_auc: 0.7259 - val_precision_4: 0.5962 - val_recall_4: 0.9394
# Epoch 30/30
# 13/13 [==============================] - 21s 2s/step - loss: 0.5024 - accuracy: 0.7625 - auc: 0.8425 - precision_4: 0.7442 - recall_4: 0.8000 - val_loss: 0.6985 - val_accuracy: 0.5758 - val_auc: 0.6823 - val_precision_4: 0.5714 - val_recall_4: 0.6061

# %% [markdown]
# - From all the 5 models we trained we can see that 2nd one was giving a better result at epoch 12.
# - We can select that model as the custom model.

# %% [markdown]
# #### **Test Evaluation for CustomNeuralNetwork2**

# %%
from NeuralNetworkTestEvaluator import NeuralNetworkTestEvaluator
from tensorflow import keras


test_model_cnn2_nano = keras.models.load_model(
    "./models/Nano/customNN2/11-22-15-48/model.keras")
cnn2NanoTestEvaluator = NeuralNetworkTestEvaluator("data/Nano", test_model_cnn2_nano, 13)
cnn2NanoTestEvaluator.evaluate_model()
# Out:
# Found 40 files belonging to 2 classes.
# Model Evaluation Results:
# --------------------------------------------------
# 2/2 [==============================] - 1s 76ms/step - loss: 0.6778 - accuracy: 0.7000 - auc: 0.7500 - precision_1: 0.6250 - recall_1: 1.0000
#
# Test Accuracy: 0.7000
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 76ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          Cat       1.00      0.40      0.57        20
#          Dog       0.62      1.00      0.77        20
#
#     accuracy                           0.70        40
#    macro avg       0.81      0.70      0.67        40
# weighted avg       0.81      0.70      0.67        40
#
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 239ms/step
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# 1/1 [==============================] - 0s 104ms/step
# {'accuracy': 0.699999988079071,
#  'confusion_matrix': array([[ 8, 12],
#         [ 0, 20]], dtype=int64),
#  'classification_metrics': {'Cat': {'precision': 1.0,
#    'recall': 0.4,
#    'f1-score': 0.5714285714285715,
#    'support': 20.0},
#   'Dog': {'precision': 0.625,
#    'recall': 1.0,
#    'f1-score': 0.7692307692307693,
#    'support': 20.0},
#   'accuracy': 0.7,
#   'macro avg': {'precision': 0.8125,
#    'recall': 0.7,
#    'f1-score': 0.6703296703296704,
#    'support': 40.0},
#   'weighted avg': {'precision': 0.8125,
#    'recall': 0.7,
#    'f1-score': 0.6703296703296704,
#    'support': 40.0}}}

# %% [markdown]
# - After evaluations we find that cats are getting misclassified as dogs.
# - All dogs were correctly identified on the test set with precision 1.
# - Accuracy is 70%.
# - We can try the same in a bigger dataset now.

# %% [markdown]
# #### **Adding Augmentation to our custom model**

# %%
from CustomNeuralNetwork2Augmented import CustomNeuralNetwork2Augmented
from NeuralNetworkEvaluator import NeuralNetworkEvaluator
from NeuralNetworkTestEvaluator import NeuralNetworkTestEvaluator


valuator = NeuralNetworkEvaluator("data/Nano")
customNN = CustomNeuralNetwork2Augmented()
customNN.model.summary()
customModel = customNN.model
valuator.trainandvalidate(customModel, "Nano","customNN2Augmented")
# Out:
# Found 400 files belonging to 2 classes.
# Found 66 files belonging to 2 classes.
# Found 40 files belonging to 2 classes.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 19, 19, 196)       100548
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 196)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 256)         451840
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 1)                 12545
#
# =================================================================
# Total params: 658,181
# Trainable params: 658,181
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 13/13 [==============================] - 12s 799ms/step - loss: 0.7000 - accuracy: 0.5125 - auc: 0.5125 - precision: 0.5152 - recall: 0.4250 - val_loss: 0.6933 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 13/13 [==============================] - 10s 780ms/step - loss: 0.6937 - accuracy: 0.4925 - auc: 0.4851 - precision: 0.4948 - recall: 0.7150 - val_loss: 0.6934 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 13/13 [==============================] - 10s 763ms/step - loss: 0.6935 - accuracy: 0.5125 - auc: 0.5178 - precision: 0.5157 - recall: 0.4100 - val_loss: 0.6916 - val_accuracy: 0.5000 - val_auc: 0.6621 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 4/30
# 13/13 [==============================] - 10s 776ms/step - loss: 0.6989 - accuracy: 0.5500 - auc: 0.5398 - precision: 0.5463 - recall: 0.5900 - val_loss: 0.6945 - val_accuracy: 0.5000 - val_auc: 0.4848 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 13/13 [==============================] - 10s 771ms/step - loss: 0.6928 - accuracy: 0.5100 - auc: 0.5298 - precision: 0.5278 - recall: 0.1900 - val_loss: 0.6907 - val_accuracy: 0.6212 - val_auc: 0.6235 - val_precision: 0.6818 - val_recall: 0.4545
# Epoch 6/30
# 13/13 [==============================] - 10s 776ms/step - loss: 0.6929 - accuracy: 0.5225 - auc: 0.5363 - precision: 0.5233 - recall: 0.5050 - val_loss: 0.6937 - val_accuracy: 0.5455 - val_auc: 0.5271 - val_precision: 0.5652 - val_recall: 0.3939
# Epoch 7/30
# 13/13 [==============================] - 10s 778ms/step - loss: 0.6823 - accuracy: 0.5950 - auc: 0.6079 - precision: 0.6080 - recall: 0.5350 - val_loss: 0.6837 - val_accuracy: 0.6061 - val_auc: 0.6097 - val_precision: 0.5714 - val_recall: 0.8485
# Epoch 8/30
# 13/13 [==============================] - 11s 807ms/step - loss: 0.6928 - accuracy: 0.5700 - auc: 0.5507 - precision: 0.5680 - recall: 0.5850 - val_loss: 0.6922 - val_accuracy: 0.5000 - val_auc: 0.5785 - val_precision: 0.5000 - val_recall: 0.9394
# Epoch 9/30
# 13/13 [==============================] - 11s 798ms/step - loss: 0.6808 - accuracy: 0.5525 - auc: 0.5869 - precision: 0.5484 - recall: 0.5950 - val_loss: 0.6764 - val_accuracy: 0.5909 - val_auc: 0.6419 - val_precision: 0.5652 - val_recall: 0.7879
# Epoch 10/30
# 13/13 [==============================] - 10s 788ms/step - loss: 0.6574 - accuracy: 0.6450 - auc: 0.6758 - precision: 0.6450 - recall: 0.6450 - val_loss: 0.8959 - val_accuracy: 0.4848 - val_auc: 0.6299 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/30
# 13/13 [==============================] - 11s 805ms/step - loss: 0.6588 - accuracy: 0.6300 - auc: 0.6671 - precision: 0.6477 - recall: 0.5700 - val_loss: 0.6994 - val_accuracy: 0.5455 - val_auc: 0.7185 - val_precision: 0.5238 - val_recall: 1.0000
# Epoch 12/30
# 13/13 [==============================] - 10s 774ms/step - loss: 0.6463 - accuracy: 0.6400 - auc: 0.6849 - precision: 0.6273 - recall: 0.6900 - val_loss: 0.6310 - val_accuracy: 0.6818 - val_auc: 0.7296 - val_precision: 0.7500 - val_recall: 0.5455
# Epoch 13/30
# 13/13 [==============================] - 10s 786ms/step - loss: 0.6087 - accuracy: 0.6725 - auc: 0.7442 - precision: 0.6575 - recall: 0.7200 - val_loss: 0.7263 - val_accuracy: 0.4848 - val_auc: 0.5891 - val_precision: 0.4889 - val_recall: 0.6667
# Epoch 14/30
# 13/13 [==============================] - 10s 774ms/step - loss: 0.5944 - accuracy: 0.6725 - auc: 0.7516 - precision: 0.6845 - recall: 0.6400 - val_loss: 0.6877 - val_accuracy: 0.6061 - val_auc: 0.6093 - val_precision: 0.6207 - val_recall: 0.5455
# Epoch 15/30
# 13/13 [==============================] - 11s 800ms/step - loss: 0.5624 - accuracy: 0.7250 - auc: 0.7923 - precision: 0.7473 - recall: 0.6800 - val_loss: 0.7147 - val_accuracy: 0.6515 - val_auc: 0.6974 - val_precision: 0.6042 - val_recall: 0.8788
# Epoch 16/30
# 13/13 [==============================] - 10s 780ms/step - loss: 0.5132 - accuracy: 0.7575 - auc: 0.8310 - precision: 0.7537 - recall: 0.7650 - val_loss: 0.7048 - val_accuracy: 0.5909 - val_auc: 0.6465 - val_precision: 0.6071 - val_recall: 0.5152
# Epoch 17/30
# 13/13 [==============================] - 11s 817ms/step - loss: 0.5171 - accuracy: 0.7500 - auc: 0.8183 - precision: 0.7551 - recall: 0.7400 - val_loss: 0.6989 - val_accuracy: 0.6212 - val_auc: 0.6602 - val_precision: 0.6111 - val_recall: 0.6667
# Epoch 18/30
# 13/13 [==============================] - 11s 798ms/step - loss: 0.4453 - accuracy: 0.7850 - auc: 0.8746 - precision: 0.8000 - recall: 0.7600 - val_loss: 1.0262 - val_accuracy: 0.6212 - val_auc: 0.7140 - val_precision: 0.5690 - val_recall: 1.0000
# Epoch 19/30
# 13/13 [==============================] - 11s 796ms/step - loss: 0.5333 - accuracy: 0.7850 - auc: 0.8426 - precision: 0.7664 - recall: 0.8200 - val_loss: 0.7855 - val_accuracy: 0.5758 - val_auc: 0.6878 - val_precision: 0.7273 - val_recall: 0.2424
# Epoch 20/30
# 13/13 [==============================] - 10s 791ms/step - loss: 0.4035 - accuracy: 0.8225 - auc: 0.9036 - precision: 0.8525 - recall: 0.7800 - val_loss: 0.7736 - val_accuracy: 0.6212 - val_auc: 0.5964 - val_precision: 0.6250 - val_recall: 0.6061
# Epoch 21/30
# 13/13 [==============================] - 11s 810ms/step - loss: 0.3788 - accuracy: 0.8250 - auc: 0.9145 - precision: 0.8421 - recall: 0.8000 - val_loss: 0.7204 - val_accuracy: 0.6061 - val_auc: 0.6997 - val_precision: 0.6296 - val_recall: 0.5152
# Epoch 22/30
# 13/13 [==============================] - 11s 817ms/step - loss: 0.3447 - accuracy: 0.8475 - auc: 0.9274 - precision: 0.8639 - recall: 0.8250 - val_loss: 0.8689 - val_accuracy: 0.5758 - val_auc: 0.6520 - val_precision: 0.5862 - val_recall: 0.5152
# Epoch 23/30
# 13/13 [==============================] - 11s 820ms/step - loss: 0.2955 - accuracy: 0.8575 - auc: 0.9486 - precision: 0.8705 - recall: 0.8400 - val_loss: 0.9545 - val_accuracy: 0.6364 - val_auc: 0.7433 - val_precision: 0.6098 - val_recall: 0.7576
# Epoch 24/30
# 13/13 [==============================] - 11s 848ms/step - loss: 0.2806 - accuracy: 0.8975 - auc: 0.9527 - precision: 0.8955 - recall: 0.9000 - val_loss: 0.9792 - val_accuracy: 0.6061 - val_auc: 0.7052 - val_precision: 0.5854 - val_recall: 0.7273
# Epoch 25/30
# 13/13 [==============================] - 11s 815ms/step - loss: 0.3237 - accuracy: 0.8825 - auc: 0.9405 - precision: 0.8844 - recall: 0.8800 - val_loss: 0.8916 - val_accuracy: 0.6818 - val_auc: 0.6827 - val_precision: 0.7143 - val_recall: 0.6061
# Epoch 26/30
# 13/13 [==============================] - 11s 808ms/step - loss: 0.1922 - accuracy: 0.9200 - auc: 0.9809 - precision: 0.9200 - recall: 0.9200 - val_loss: 0.9565 - val_accuracy: 0.6515 - val_auc: 0.6983 - val_precision: 0.6250 - val_recall: 0.7576
# Epoch 27/30
# 13/13 [==============================] - 11s 820ms/step - loss: 0.4182 - accuracy: 0.8875 - auc: 0.9255 - precision: 0.9101 - recall: 0.8600 - val_loss: 1.0991 - val_accuracy: 0.6818 - val_auc: 0.6919 - val_precision: 0.6765 - val_recall: 0.6970
# Epoch 28/30
# 13/13 [==============================] - 11s 839ms/step - loss: 0.1699 - accuracy: 0.9400 - auc: 0.9849 - precision: 0.9400 - recall: 0.9400 - val_loss: 0.9878 - val_accuracy: 0.6970 - val_auc: 0.7461 - val_precision: 0.7097 - val_recall: 0.6667
# Epoch 29/30
# 13/13 [==============================] - 11s 844ms/step - loss: 0.1209 - accuracy: 0.9600 - auc: 0.9937 - precision: 0.9510 - recall: 0.9700 - val_loss: 1.2160 - val_accuracy: 0.6364 - val_auc: 0.6827 - val_precision: 0.6452 - val_recall: 0.6061
# Epoch 30/30
# 13/13 [==============================] - 13s 1s/step - loss: 0.1785 - accuracy: 0.9300 - auc: 0.9781 - precision: 0.9388 - recall: 0.9200 - val_loss: 1.2377 - val_accuracy: 0.6212 - val_auc: 0.6846 - val_precision: 0.6053 - val_recall: 0.6970

# %% [markdown]
# #### **Evaluations for augmented Model**

# %%
from NeuralNetworkTestEvaluator import NeuralNetworkTestEvaluator
from tensorflow import keras


test_model_cnn2augmented_nano = keras.models.load_model(
    "./models/Nano/customNN2Augmented/11-22-18-59/model.keras")
cnn2AugmentedNanoTestEvaluator = NeuralNetworkTestEvaluator("data/Nano", test_model_cnn2augmented_nano, 13)
cnn2AugmentedNanoTestEvaluator.evaluate_model()
# Out:
# Found 40 files belonging to 2 classes.
# Model Evaluation Results:
# --------------------------------------------------
# 2/2 [==============================] - 1s 73ms/step - loss: 0.6533 - accuracy: 0.7500 - auc: 0.7962 - precision: 0.7778 - recall: 0.7000
#
# Test Accuracy: 0.7500
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 73ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          Cat       0.73      0.80      0.76        20
#          Dog       0.78      0.70      0.74        20
#
#     accuracy                           0.75        40
#    macro avg       0.75      0.75      0.75        40
# weighted avg       0.75      0.75      0.75        40
#
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 188ms/step
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 1 Predicted: 0
# Actual : 1 Predicted: 0
# Actual : 1 Predicted: 0
# Actual : 1 Predicted: 0
# 1/1 [==============================] - 0s 65ms/step
# Actual : 1 Predicted: 0
# Actual : 1 Predicted: 0
# {'accuracy': 0.75,
#  'confusion_matrix': array([[16,  4],
#         [ 6, 14]], dtype=int64),
#  'classification_metrics': {'Cat': {'precision': 0.7272727272727273,
#    'recall': 0.8,
#    'f1-score': 0.761904761904762,
#    'support': 20.0},
#   'Dog': {'precision': 0.7777777777777778,
#    'recall': 0.7,
#    'f1-score': 0.7368421052631577,
#    'support': 20.0},
#   'accuracy': 0.75,
#   'macro avg': {'precision': 0.7525252525252526,
#    'recall': 0.75,
#    'f1-score': 0.7493734335839599,
#    'support': 40.0},
#   'weighted avg': {'precision': 0.7525252525252526,
#    'recall': 0.75,
#    'f1-score': 0.7493734335839598,
#    'support': 40.0}}}

# %% [markdown]
# - After Augmentation was added to the dataset we find an increase in accuracy. ie from 71-75
# - Precision has gone up for cats also. from 0.4 - 0.72
# - We can see that the when accuracy is 0.75 recall attains a 0.8 value using curve as well.
# - Unlike the model without augmentation we can now see that misclassification happens for both the classes. We can see images from both classes getting misclassified and some of them are difficult to judge even for humans.
#
# > We can try the VGG-16 model now.

# %% [markdown]
# #### **VGG-16**

# %%
from CustomVGG16 import CustomVGG16
from NeuralNetworkEvaluatorVGG import NeuralNetworkEvaluatorVGG
from NeuralNetworkTestEvaluatorVGG import NeuralNetworkTestEvaluatorVGG


valuator = NeuralNetworkEvaluatorVGG("data/Nano")
customVGG16 = CustomVGG16()
customVGG16.model.summary()
customModel = customVGG16.model
valuator.trainandvalidate(customModel, "Nano","CustomVGG16",20)
# Out:
# Found 400 files belonging to 2 classes.
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_MapDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# Found 66 files belonging to 2 classes.
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_MapDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# Found 40 files belonging to 2 classes.
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_MapDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 180, 180, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 180, 180, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 90, 90, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 90, 90, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 90, 90, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 45, 45, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 45, 45, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# KerasTensor(type_spec=TensorSpec(shape=(None, 5, 5, 512), dtype=tf.float32, name=None), name='vgg16/block5_pool/MaxPool:0', description="created by layer 'vgg16'")
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  vgg16 (Functional)          (None, 5, 5, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 12800)             0
#
#  dense_2 (Dense)             (None, 256)               3277056
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 17,992,001
# Trainable params: 3,277,313
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 13/13 [==============================] - 49s 4s/step - loss: 24.9507 - accuracy: 0.8150 - auc: 0.8207 - precision_1: 0.8119 - recall_1: 0.8200 - val_loss: 4.4212 - val_accuracy: 0.8788 - val_auc: 0.8788 - val_precision_1: 1.0000 - val_recall_1: 0.7576
# Epoch 2/20
# 13/13 [==============================] - 51s 4s/step - loss: 0.8344 - accuracy: 0.9775 - auc: 0.9799 - precision_1: 0.9799 - recall_1: 0.9750 - val_loss: 0.2658 - val_accuracy: 0.9697 - val_auc: 0.9688 - val_precision_1: 1.0000 - val_recall_1: 0.9394
# Epoch 3/20
# 13/13 [==============================] - 52s 4s/step - loss: 0.0682 - accuracy: 0.9975 - auc: 0.9975 - precision_1: 0.9950 - recall_1: 1.0000 - val_loss: 0.6318 - val_accuracy: 0.9697 - val_auc: 0.9697 - val_precision_1: 1.0000 - val_recall_1: 0.9394
# Epoch 4/20
# 13/13 [==============================] - 52s 4s/step - loss: 0.0858 - accuracy: 0.9950 - auc: 0.9950 - precision_1: 0.9950 - recall_1: 0.9950 - val_loss: 0.5731 - val_accuracy: 0.9697 - val_auc: 0.9697 - val_precision_1: 1.0000 - val_recall_1: 0.9394
# Epoch 5/20
# 13/13 [==============================] - 56s 4s/step - loss: 1.1917 - accuracy: 0.9675 - auc: 0.9674 - precision_1: 0.9652 - recall_1: 0.9700 - val_loss: 2.8214 - val_accuracy: 0.9242 - val_auc: 0.9242 - val_precision_1: 1.0000 - val_recall_1: 0.8485
# Epoch 6/20
# 13/13 [==============================] - 53s 4s/step - loss: 8.3664e-05 - accuracy: 1.0000 - auc: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 2.5426 - val_accuracy: 0.9242 - val_auc: 0.9242 - val_precision_1: 1.0000 - val_recall_1: 0.8485
# Epoch 7/20
# 13/13 [==============================] - 52s 4s/step - loss: 2.0299e-05 - accuracy: 1.0000 - auc: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 2.3851 - val_accuracy: 0.9242 - val_auc: 0.9242 - val_precision_1: 1.0000 - val_recall_1: 0.8485
# Epoch 8/20
# 13/13 [==============================] - 51s 4s/step - loss: 0.1045 - accuracy: 0.9950 - auc: 0.9950 - precision_1: 0.9950 - recall_1: 0.9950 - val_loss: 1.7816 - val_accuracy: 0.9242 - val_auc: 0.9242 - val_precision_1: 1.0000 - val_recall_1: 0.8485
# Epoch 9/20
# 13/13 [==============================] - 53s 4s/step - loss: 0.1289 - accuracy: 0.9925 - auc: 0.9925 - precision_1: 0.9950 - recall_1: 0.9900 - val_loss: 0.3228 - val_accuracy: 0.9545 - val_auc: 0.9697 - val_precision_1: 1.0000 - val_recall_1: 0.9091
# Epoch 10/20
# 13/13 [==============================] - 52s 4s/step - loss: 2.7603e-04 - accuracy: 1.0000 - auc: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 1.2741 - val_accuracy: 0.9394 - val_auc: 0.9394 - val_precision_1: 1.0000 - val_recall_1: 0.8788
# Epoch 11/20
# 13/13 [==============================] - 53s 4s/step - loss: 7.9410e-09 - accuracy: 1.0000 - auc: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 1.2738 - val_accuracy: 0.9394 - val_auc: 0.9394 - val_precision_1: 1.0000 - val_recall_1: 0.8788
# Epoch 12/20
# 13/13 [==============================] - 53s 4s/step - loss: 3.7977e-13 - accuracy: 1.0000 - auc: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 1.2738 - val_accuracy: 0.9394 - val_auc: 0.9394 - val_precision_1: 1.0000 - val_recall_1: 0.8788
# Epoch 13/20
# 13/13 [==============================] - 179s 15s/step - loss: 0.2763 - accuracy: 0.9950 - auc: 0.9950 - precision_1: 0.9950 - recall_1: 0.9950 - val_loss: 2.3662 - val_accuracy: 0.9242 - val_auc: 0.9242 - val_precision_1: 1.0000 - val_recall_1: 0.8485
# Epoch 14/20
# 13/13 [==============================] - 66s 5s/step - loss: 0.0251 - accuracy: 0.9950 - auc: 0.9975 - precision_1: 0.9950 - recall_1: 0.9950 - val_loss: 0.5685 - val_accuracy: 0.9848 - val_auc: 0.9848 - val_precision_1: 0.9706 - val_recall_1: 1.0000
# Epoch 15/20
# 13/13 [==============================] - 53s 4s/step - loss: 0.0553 - accuracy: 0.9925 - auc: 0.9950 - precision_1: 0.9900 - recall_1: 0.9950 - val_loss: 1.9050 - val_accuracy: 0.9242 - val_auc: 0.9394 - val_precision_1: 1.0000 - val_recall_1: 0.8485
# Epoch 16/20
# 13/13 [==============================] - 55s 4s/step - loss: 0.5673 - accuracy: 0.9925 - auc: 0.9925 - precision_1: 0.9950 - recall_1: 0.9900 - val_loss: 0.7676 - val_accuracy: 0.9545 - val_auc: 0.9545 - val_precision_1: 1.0000 - val_recall_1: 0.9091
# Epoch 17/20
# 13/13 [==============================] - 63s 5s/step - loss: 4.4463e-06 - accuracy: 1.0000 - auc: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 0.6847 - val_accuracy: 0.9545 - val_auc: 0.9545 - val_precision_1: 1.0000 - val_recall_1: 0.9091
# Epoch 18/20
# 13/13 [==============================] - 61s 5s/step - loss: 0.0372 - accuracy: 0.9975 - auc: 0.9975 - precision_1: 1.0000 - recall_1: 0.9950 - val_loss: 1.6719e-06 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision_1: 1.0000 - val_recall_1: 1.0000
# Epoch 19/20
# 13/13 [==============================] - 56s 4s/step - loss: 3.8762e-05 - accuracy: 1.0000 - auc: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 0.3628 - val_accuracy: 0.9848 - val_auc: 0.9848 - val_precision_1: 1.0000 - val_recall_1: 0.9697
# Epoch 20/20
# 13/13 [==============================] - 68s 5s/step - loss: 0.0347 - accuracy: 0.9950 - auc: 0.9975 - precision_1: 0.9950 - recall_1: 0.9950 - val_loss: 0.5309 - val_accuracy: 0.9697 - val_auc: 0.9697 - val_precision_1: 1.0000 - val_recall_1: 0.9394

# %% [markdown]
# #### **Test Evaluation of VGG-16**

# %%
from NeuralNetworkTestEvaluatorVGG import NeuralNetworkTestEvaluatorVGG
from tensorflow import keras


test_model_vgg_nano = keras.models.load_model(
    "./models/Nano/customVGG16/11-22-20-48/model.keras")
vggTestEvaluator = NeuralNetworkTestEvaluatorVGG("data/Nano", test_model_vgg_nano, 13)
vggTestEvaluator.evaluate_model()
# Out:
# Found 40 files belonging to 2 classes.
# Model Evaluation Results:
# --------------------------------------------------
# 2/2 [==============================] - 5s 890ms/step - loss: 1.6963 - accuracy: 0.9250 - auc: 0.9488 - precision_1: 0.9048 - recall_1: 0.9500
#
# Test Accuracy: 0.9250
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 1s 944ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 1s 884ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          Cat       0.95      0.90      0.92        20
#          Dog       0.90      0.95      0.93        20
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.93      0.92        40
# weighted avg       0.93      0.93      0.92        40
#
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 1s 871ms/step
# 1/1 [==============================] - 4s 4s/step
# Actual : 0 Predicted: 1
# Actual : 0 Predicted: 1
# Actual : 1 Predicted: 0
# 1/1 [==============================] - 1s 920ms/step
# {'accuracy': 0.925000011920929,
#  'confusion_matrix': array([[18,  2],
#         [ 1, 19]], dtype=int64),
#  'classification_metrics': {'Cat': {'precision': 0.9473684210526315,
#    'recall': 0.9,
#    'f1-score': 0.9230769230769231,
#    'support': 20.0},
#   'Dog': {'precision': 0.9047619047619048,
#    'recall': 0.95,
#    'f1-score': 0.9268292682926829,
#    'support': 20.0},
#   'accuracy': 0.925,
#   'macro avg': {'precision': 0.9260651629072681,
#    'recall': 0.925,
#    'f1-score': 0.924953095684803,
#    'support': 40.0},
#   'weighted avg': {'precision': 0.9260651629072681,
#    'recall': 0.925,
#    'f1-score': 0.924953095684803,
#    'support': 40.0}}}

# %% [markdown]
# - Awesome results after applying VGG-16.
# - The accuracy went from 75% in the custom model to 92.5% in the VGG-16 model even without using augmentation.
# - Precision and recall also improved significantly and the AUC curve is showing very good results.
# - One of the images that is misclassified is difficult to identify for humans also. ( the last one )
