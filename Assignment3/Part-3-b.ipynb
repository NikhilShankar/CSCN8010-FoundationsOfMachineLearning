# %% [markdown]
# > We tried small variation of the base model but couldn't find any improvements in accuracy as per the graphs plotted.
# >> Trying with removal of maxpooling at the start of the neural network architecture.

# %%
from CustomNeuralNetwork6 import CustomNeuralNetwork6
from NeuralNetworkEvaluator import NeuralNetworkEvaluator

valuator = NeuralNetworkEvaluator("data/Nano")
customNN = CustomNeuralNetwork6()
customNN.model.summary()
customModel = customNN.model
valuator.trainandvalidate(customModel, "Nano","customNN6", epochs_one=20)
# Out:
# 13/13 [==============================] - 43s 3s/step - loss: 0.7311 - accuracy: 0.4650 - auc: 0.4481 - precision_3: 0.4375 - recall_3: 0.2450 - val_loss: 0.6937 - val_accuracy: 0.5000 - val_auc: 0.5487 - val_precision_3: 0.5000 - val_recall_3: 1.0000
# Epoch 2/20
#  4/13 [========>.....................] - ETA: 30s - loss: 0.7198 - accuracy: 0.4844 - auc: 0.4151 - precision_3: 0.4844 - recall_3: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       6 customNN.model.summary()
#       7 customModel = customNN.model
# ----> 8 valuator.trainandvalidate(customModel, "Nano","customNN6", epochs_one=20)
#
# File c:\Users\DELL\Desktop\Conestoga\AIML\FoundationsMachineLearningFramework\git\CSCN8010\Assignment3\NeuralNetworkEvaluator.py:49, in NeuralNetworkEvaluator.trainandvalidate(self, model, datasetType, modelname, epochs_one)
# ...

# %% [markdown]
# #### **Evaluating on Test Set**

# %%
from NeuralNetworkTestEvaluator import NeuralNetworkTestEvaluator
from tensorflow import keras

test_model_cnn6_nano = keras.models.load_model(
    "./models/Nano/customNN6/11-22-15-55/model.keras")


cnn6NanoTestEvaluator = NeuralNetworkTestEvaluator(test_model_cnn6_nano, "data/Nano")
cnn6NanoTestEvaluator.evaluate_model()
